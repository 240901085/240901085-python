# %% [markdown]
# <a href="https://colab.research.google.com/github/240901085/240901085-python/blob/main/pandas3(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
arr=np.array(['P','a','n','d','a','s'])
a=pd.Series(arr)
print("Series from array")
print(a)
# Out:
# Series from array
# 0    P
# 1    a
# 2    n
# 3    d
# 4    a
# 5    s
# dtype: object

# %%
arr={'x':0.,'y':1.,'z':2.,}
b=pd.Series(arr)
print("\nSeries from dictionary:\n")
print(b)
# Out:
# Series from dictionary:
#
# x    0.0
# y    1.0
# z    2.0
# dtype: float64

# %%
x=pd.Series(14,index=[0,1,2,3])
print("\nSeries using scalar\n")
print(x)
# Out:
# Series using scalar
#
# 0    14
# 1    14
# 2    14
# 3    14
# dtype: int64

# %%
x=pd.Series([1,2,3],index=['a','b','c'])
print("Series through index:")
print(x)
# Out:
# Series through index:
# a    1
# b    2
# c    3
# dtype: int64

# %%
a=pd.Series(data=[1,2,3,4])
print("\n a series:\n",a)
print("\nIndex:\n",a.index)
print("\nValues:\n",a.values)
print("\nShape:",a.shape)
print("\nDimension:",a.ndim)
print("\nSize:",a.size)
# Out:
#  a series:
#  0    1
# 1    2
# 2    3
# 3    4
# dtype: int64
#
# Index:
#  RangeIndex(start=0, stop=4, step=1)
#
# Values:
#  [1 2 3 4]
#
# Shape: (4,)
#
# Dimension: 1
#
# Size: 4
