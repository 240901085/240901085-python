# %% [markdown]
# <a href="https://colab.research.google.com/github/240901085/240901085-python/blob/main/text%20file%20and%20json%20operations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Open a text file in'Write' mode to write given lines
f=open("textfile.txt",'w')
f.write("first line\n")
f.write("second line\n")
f.write("third line\n")
f.close()
k=open("textfile.txt",'r')
print(k.readline())
print(k.readline())
print(k.readline())
k.close()
# Out:
# first line
#
# second line
#
# third line

# %%
m=open("textfile.txt",'a')
m.write("fourth line\n")
m.write("fifth line\n")
m.close()
p=open("textfile.txt",'r')
print(p.read())
p.close()
# Out:
# first line
# second line
# third line
# fourth line
# fifth line

# %%
with open("textfile.txt",'r')as file:
  lines=file.readlines()
  print(lines)
# Out:
# ['first line\n', 'second line\n', 'third line\n', 'fourth line\n', 'fifth line\n']

# %%
import json
x='{"name":"John","age":30,"city":"New York"}'
y=json.loads(x)
print(y['age'])
# Out:
# 30

# %%
data={ "name":"john","age":30,"city":"New York"}
json_data=json.dumps(data)
print(json_data)
# Out:
# {"name": "john", "age": 30, "city": "New York"}
